# %%
import numpy as np
import pandas as pd 


df = pd.read_csv("adult.data.csv")
df = pd.DataFrame(df)
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
higher_education = df['education'].isin(['Bachelors','Masters' ,'Doctorate']).mean() * 100
lower_education = (~df['education'].isin(['Bachelors','Masters' ,'Doctorate'])).mean() * 100

# %%
lower_education_rich = (~df[(df['salary'] == '>50K') & (~df['education'].isin(['Bachelors','Masters' ,'Doctorate']))]).mean()
lower_education_rich
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 lower_education_rich = (~df[(df['salary'] == '>50K') & (~df['education'].isin(['Bachelors','Masters' ,'Doctorate']))]).mean()
#       2 lower_education_rich
#
# File c:\Users\Fares\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:1574, in NDFrame.__invert__(self)
#    1570 if not self.size:
#    1571     # inv fails with 0 len
#    1572     return self.copy(deep=False)
# -> 1574 new_data = self._mgr.apply(operator.invert)
#    1575 res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    1576 return res.__finalize__(self, method="__invert__")
#
# File c:\Users\Fares\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
# ...

# %%
lower_education
# Out:
# 76.99394981726606

# %%
rich = higher_education

# %%
df['salary'] == '>50K'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557     True
# 32558    False
# 32559    False
# 32560     True
# Name: salary, Length: 32561, dtype: bool

# %%
lower_education
# Out:
# 13.374896348392248

# %%
df['salary'].value_counts()
# Out:
# salary
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 32561

# %%
df['hours-per-week'].min()
# Out:
# 1

# %%
(df['salary'] == '>50K') & (df['hours-per-week'] == 1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32561, dtype: bool

# %%
top_IN_occupation = df[(df['salary'] == '>50K') & (df['native-country'] == 'India')].value_counts().get('occupation')
top_IN_occupation

# %%
n = df[df['salary'] == '>50K']['education'].isin(['Bachelors','Masters' ,'Doctorate'])
len(n)
#higher_education
#higher_education_rich = higher_education['salary'] == '>50K'
# Out:
# 7841

# %%
df.columns[:4]
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
i = 0 
c = 0 

while True:
    i +=1 
    if i == 10 :
        c+=1 
        i=0
    if c==3:
        print('bow')
        continue
# Out:
# bow
# bow
# bow
# bow
# bow
# bow
# bow
# bow
# bow
# bow
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[70], line 4
#       1 i = 0
#       2 c = 0
# ----> 4 while True:
#       5     i +=1
#       6     if i == 10 :
#
# KeyboardInterrupt:
